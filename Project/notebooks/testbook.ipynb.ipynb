# %%
display(dbutils.fs.ls("Workspace/Users/deepeshvcd6273@gmail.com/2-Months-Tasks/data"))

# %%
import pandas as pd
import os
import glob

SOURCE_DIR = "/Workspace/Users/deepeshvcd6273@gmail.com/2-Months-Tasks/data/"

# Get all files with 'claims' in the name
claims_files = glob.glob(os.path.join(SOURCE_DIR, "*claims*"))

print(f"Found {len(claims_files)} file(s): {claims_files}")

# Read and combine all
df = pd.concat([pd.read_csv(f) for f in claims_files], ignore_index=True)

print(df.shape)
display(df.head())
